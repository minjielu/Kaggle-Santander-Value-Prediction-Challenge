# %%
import pandas as pd

# %%
train = pd.read_csv('./train.csv')

# %%
train.loc[train['9884166a7'] == 4240666.66]
# Out:
#              ID     target  48df886f9  0deb4b6a8  34b15f335  a8cb14b00  \
# 3153  b7ce05853  7104000.0        0.0          0        0.0          0
#
#       2f0771a37  30347e683  d08d1fbe3  6ee66e115    ...      3ecc09859  \
# 3153          0          0          0          0    ...            0.0
#
#       9281abeea  8675bec0b  3a13ed79a  f677d4d13  71b203550  137efaa80  \
# 3153        0.0        0.0          0          0          0          0
#
#       fb36b89d9  7e293fbaf  9fc776466
# 3153          0          0          0
#
# [1 rows x 4993 columns]

# %%
columns = ['9884166a7', 'beb7f98fd', 'fd99c18b5', 'd83a2b684', '18c35d2ea',
       '0c8063d63', '400e9303d', 'c976a87ad', '8a088af55', '5f341a818',
       '5dca793da', 'db147ffca','762cbd0ab', 'fb5a3097e', '8c0a1fa32',
       '01005e5de', '47cd6e6e4', 'f58fb412c', 'a1db86e3b', '50e4f96cf',
       'f514fdb2e', '7a7da3079', 'bb1113dbb']

# %%
len(columns)
# Out:
# 23

# %%
train.loc[train[columns[13]] == 4240666.66]
# Out:
#              ID       target  48df886f9  0deb4b6a8  34b15f335  a8cb14b00  \
# 169   09ae920d2  11852000.00        0.0          0        0.0          0
# 470   1b496f5ad   7872000.00        0.0          0        0.0          0
# 534   1f2587bea  16370000.00        0.0          0        0.0          0
# 539   1f4ce0d39   2690000.00        0.0          0        0.0          0
# 664   25e7a9b47   3952000.00        0.0          0        0.0          0
# 1941  7077b2d9e   2038000.00        0.0          0        0.0          0
# 2067  781a2c850   7146000.00        0.0          0        0.0          0
# 2609  993d2b7ed   5162000.00        0.0          0        0.0          0
# 2882  a8a0cc490   5937000.00        0.0          0        0.0          0
# 2916  aac41aea0   1275333.34        0.0          0        0.0          0
# 3153  b7ce05853   7104000.00        0.0          0        0.0          0
# 3743  d6486b513   9180000.00        0.0          0        0.0          0
#
# ...

# %%
# 2067 and 2882? 
rows = [3153,470,169,1941,2916,534,664,2609,2882,2067,539,3743,3160,3423,924,3175,1067]

# %%
new_index = list(train.loc[train[columns[23]] == 4240666.66].index)
for item in new_index:
    if item not in rows:
        print(item)
        break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-19eaff50de34> in <module>()
# ----> 1 new_index = list(train.loc[train[columns[23]] == 4240666.66].index)
#       2 for item in new_index:
#       3     if item not in rows:
#       4         print(item)
#       5         break
#
# IndexError: list index out of range

# %%
len(columns)
# Out:
# 23

# %%
pd.set_option('display.max_columns',100)
train.loc[rows,['f190486d6','eeb9cd3aa','target']+columns]
# Out:
#        f190486d6    eeb9cd3aa       target   9884166a7   beb7f98fd  \
# 3153         0.0         0.00   7104000.00  4240666.66  4240666.66
# 470          0.0         0.00   7872000.00  6592000.00  4240666.66
# 169    7104000.0         0.00  11852000.00  2735000.00  6592000.00
# 1941   7872000.0         0.00   2038000.00  1908000.00  2735000.00
# 2916  11852000.0   7104000.00   1275333.34        0.00  1908000.00
# 534    2038000.0   7872000.00  16370000.00  5718000.00        0.00
# 664   16370000.0   2038000.00   3952000.00  3340800.00  3249500.00
# 2609         0.0   1275333.34   5162000.00   663000.00  3340800.00
# 2882   3952000.0  16370000.00   5937000.00   968000.00   663000.00
# 2067   5162000.0         0.00   7146000.00  4188500.00   968000.00
# 539    7146000.0   5162000.00   2690000.00  1586666.66   723615.00
# 3743         0.0   5937000.00   9180000.00  3801250.00  1586666.66
# 3160   2690000.0   7146000.00  16720000.00  4133333.34  3801250.00
# ...

# %%
row = train.loc[664]

# %%
row[row == 7104000.00]
# Out:
# eeb9cd3aa    2.038e+06
# Name: 664, dtype: object

# %%
### New_leak: 4240666.66
train_leak = pd.read_csv('./train_leak_new.csv')

# %%
train_leak.loc[rows,'compiled_leak_new']
# Out:
# 3153            NaN
# 470             NaN
# 169             NaN
# 1941     2038000.00
# 2916     1275333.34
# 534     16370000.00
# 664      3952000.00
# 2609     5162000.00
# 2882     5937000.00
# 2067     7146000.00
# 539      2690000.00
# 3743     9180000.00
# 3160    16720000.00
# 3423     9948000.00
# 924      1326666.66
# 3175     5786000.00
# 1067     2962000.00
# Name: compiled_leak_new, dtype: float64
